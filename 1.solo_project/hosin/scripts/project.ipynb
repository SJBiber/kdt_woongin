# %%
import pandas as pd
import numpy as np
import os
from setting import *

# %%
os.getcwd()
# Out:
# '/Users/baeseungjae/Documents/project/프로젝트'

# %%
crime_2023 = pd.read_excel(io = '년도별_범죄_리스트.xlsx',
                           skiprows = 2,
                           usecols = range(1,7),
                           sheet_name = '2023')
crime_2024 = pd.read_excel(io = '년도별_범죄_리스트.xlsx',
                           skiprows = 2,
                           sheet_name = '2024',
                           usecols = range(1,7))
crime_2025 = pd.read_excel(io = '년도별_범죄_리스트.xlsx',
                           skiprows = 2,
                           sheet_name = '2025',
                           usecols = range(1,7))

# %%
crime_2023['뉴스언급일'] = pd.to_datetime('2023년 '+ crime_2023['뉴스언급일'] , format='%Y년 %m월 %d일')

# %%
crime_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   발생일             30 non-null     object
#  1   뉴스언급일           30 non-null     datetime64[ns]
#  2   국가              30 non-null     object
#  3   사건명 및 내용        30 non-null     object
#  4   파급력             30 non-null     object
#  5   참고 뉴스 및 링크 키워드  30 non-null     object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 1.5+ KB

# %%
crime_2023['월'] = crime_2023['뉴스언급일'].dt.month

# %%
crime_2023
# Out:
#         발생일      뉴스언급일    국가                      사건명 및 내용 파급력  \
# 0    1월 15일 2023-01-16    한국    동두천 전 여친 흉기 폭행: 보복 목적 강력범죄   하
# 1    1월 20일 2023-01-20    한국   강남 개포동 모녀 살해: 빚 청산 목적 강력 범죄   중
# 2    2월 10일 2023-02-12    한국   평택항 환전소 강도 사건: 1000만원 갈취 도주   하
# 3    3월 12일 2023-03-14   러시아   한인 선교사 간첩 혐의 체포: 한국인 러시아 구금   상
# 4    3월 29일 2023-03-31    한국     강남 역삼동 납치 살인: 코인 탈취 목적 납치   상
# 5    4월 12일 2023-04-13    한국   강남 중학생 SNS 투신 생중계: 온라인 커뮤니티   중
# 6     5월 4일 2023-05-05    한국    구로구 환전소 강도 살인: 현금 뺏고 주인 살해   중
# 7    5월 10일 2023-05-15   베트남   호찌민 가방 시신 사건: 한인 간 금전 갈등 살인   상
# 8    5월 22일 2023-05-23    한국     부산 돌려차기 사건: 강간살인미수 징역 20년   상
# 9    5월 26일 2023-05-27    한국    정유정 살인 사건: 과외 앱으로 만난 또래 살해  최상
# 10    6월 6일 2023-06-11  캄보디아     BJ 아영 사망 사건: 시신이 웅덩이에서 발견   상
# 11   6월 15일 2023-06-16   필리핀    세부 한인 식당 총기 협박: 교민 간 갈등 위협   중
# 12   7월 21일 2023-07-21    한국  신림역 흉기 난동 (조선): 1명 사망, 3명 부상  최상
# 13   7월 24일 2023-07-24    한국     신림역 20명 살해 예고: 커뮤니티 첫 예고글   상
# ...

# %%
# 2023년도 파급력있던 범죄가 일어났던 월별 개수 저장
crime_2023_month_total = crime_2023.groupby(by='월')['파급력'].count()

# 2023년도 범죄가 가장 많이 일어났던 달을 빨간색으로 강조
colors = ['red' if x == crime_2023_month_total.max() else 'blue' for x in crime_2023_month_total]
crime_2023_month_total.plot(kind = 'bar', color = colors)
plt.ylim(0,10)
plt.xlabel('월')
plt.ylabel('범죄 기사 개수')
for i ,v in enumerate(crime_2023_month_total):
    plt.text(i,v,f'{v} 개' , ha = 'center' , va = 'bottom')

plt.title('2023년도 큰 범죄 사고 그래프' , fontweight='bold')
# Out:
# Text(0.5, 1.0, '2023년도 큰 범죄 사고 그래프')

# %%
crime_2024['뉴스언급일'] = pd.to_datetime('2024년 '+ crime_2024['뉴스언급일'] , format='%Y년 %m월 %d일')

# %%
crime_2024['월'] = crime_2024['뉴스언급일'].dt.month

# %%
crime_2024
# Out:
#         발생일      뉴스언급일     국가                      사건명 및 내용 파급력  \
# 0     1월 2일 2024-01-02     한국    이재명 대표 피습 사건: 정치 테러 초유의 사태  최상
# 1     1월 5일 2024-01-05     한국    일본 대사관 폭파 협박 팩스: 국제적 허위 협박   중
# 2    2월 14일 2024-02-15     한국   인천 오피스텔 성폭행 살인: 평소 알던 여성 범행   중
# 3    3월 20일 2024-03-20     한국  고척돔 MLB 개막전 테러 협박: 오타니 겨냥 협박   상
# 4    4월 10일 2024-04-11     한국    파주 호텔 여성 2명 살인: 유인 후 강도 살인   중
# 5    4월 20일 2024-04-20     한국      대전 70대 노인 묻지마 폭행: 무차별 습격   하
# 6    3월 25일 2024-04-22     한국    화성 오피스텔 살인 (김레아): 모녀 흉기 공격   상
# 7     5월 6일 2024-05-07     한국     강남역 의대생 여친 살해: 옥상에서 계획 살인  최상
# 8     5월 4일 2024-05-12     태국  파타야 드럼통 살인 사건: 한국인 관광객 납치 살해  최상
# 9    5월 12일 2024-05-13    베트남   하노이 호텔 한인 여성 살인: 연인 간 강력 범죄   중
# 10   5월 22일 2024-05-23     한국   서울역 50명 살인 예고: 30대 남성 실형 선고   중
# 11   5월 30일 2024-05-31     한국   대치동 모녀 살인 (박학선): 전 여친과 딸 살해   상
# 12   6월 11일 2024-06-11     한국      강남역 매장 인질극: 40대 남성 흉기 난동   하
# 13   7월 20일 2024-07-21  말레이시아       한인 인플루언서 감금: 괴한들의 납치 시도   중
# ...

# %%
crime_2024_month_total = crime_2024.groupby(by = '월')['파급력'].count()

# %%
colors = ['red' if x == crime_2024_month_total.max() else 'blue' for x in crime_2024_month_total]
crime_2024_month_total.plot(kind = 'bar', color = colors)
plt.ylim(0,10)
plt.xlabel('월')
plt.ylabel('범죄 기사 개수')
for i ,v in enumerate(crime_2024_month_total):
    plt.text(i,v,f'{v} 개' , ha = 'center' , va = 'bottom')

plt.title('2024년도 큰 범죄 사고 그래프' , fontweight='bold')
# Out:
# Text(0.5, 1.0, '2024년도 큰 범죄 사고 그래프')

# %%
crime_2025['뉴스언급일'] = pd.to_datetime('2025년 '+ crime_2025['뉴스언급일'] , format='%Y년 %m월 %d일')

# %%
crime_2025['월'] = crime_2025['뉴스언급일'].dt.month

# %%
crime_2025
# Out:
#         발생일      뉴스언급일      국가                        사건명 및 내용 파급력  \
# 0     1월 2일 2025-01-02      한국       강원 교육청 폭파 예고: 새해 업무 마비 시도   하
# 1    1월 10일 2025-01-12  마다가스카르        한인 선교사 피살: 현지 강도 습격으로 사망   중
# 2    2월 20일 2025-02-21     필리핀      한인 관광객 총격 사망: 마닐라 인근 강력 범죄   중
# 3     3월 5일 2025-03-06     라오스       한인 실종 사망 사건: 등산로 인근 시신 발견   하
# 4    3월 18일 2025-03-19      한국    부산 중학생 집단 폭행 살해: 동급생 간 가혹 행위   중
# 5    4월 15일 2025-04-16      한국    경찰관 사칭 강도·성범죄: 가짜 경찰 공무원증 활용   상
# 6    5월 10일 2025-05-11      한국    제주 관광객 납치 감금: 금품 요구 목적 강력 범죄   중
# 7    6월 20일 2025-06-22     베트남      다낭 한인 실종 및 사망: 타살 정황 발견 수사   하
# 8    7월 15일 2025-07-16      한국  대전 교제 살인 및 빈소 난입: 전 여친 살해 후 방문   중
# 9    7월 30일 2025-08-01      한국     울산 교제 폭력 납치 미수: 차량 강제 납치 시도   중
# 10    8월 5일 2025-08-05      한국    전국 백화점 연쇄 폭파 예고: 신세계 등 대피 소동   중
# 11    8월 8일 2025-08-08      한국        고척돔 공연장 테러 예고: 대형 콘서트 겨냥   중
# 12   8월 10일 2025-08-10      한국   학생 대상 황산 테러 예고글: 교육 시설 무차별 위협   중
# ...

# %%
crime_2025_month_total = crime_2025.groupby(by = '월')['파급력'].count()

# %%
colors = ['red' if x == crime_2025_month_total.max() else 'blue' for x in crime_2025_month_total]
crime_2025_month_total.plot(kind = 'bar', color = colors)
plt.ylim(0,10)
plt.xlabel('월')
plt.ylabel('범죄 기사 개수')
for i ,v in enumerate(crime_2025_month_total):
    plt.text(i,v,f'{v} 개' , ha = 'center' , va = 'bottom')
plt.title('2025년도 큰 범죄 사고 그래프' , fontweight='bold')
# Out:
# Text(0.5, 1.0, '2025년도 큰 범죄 사고 그래프')

# %%
os.listdir()
# Out:
# ['2025_남자_호신용품_쇼핑_검색.csv',
#  '2023_2030세대_호신용품_쇼핑_검색.csv',
#  '2025_여자_호신용품_쇼핑_검색.csv',
#  '2025_2030세대_호신용관련_검색.xlsx',
#  '2024_4050세대_호신용품_vs_가정용방범장치_쇼핑_검색.csv',
#  '2024_2030세대_호신용품_쇼핑_검색.csv',
#  '2024_4050세대_호신용관련_검색.xlsx',
#  '2025_2030세대_호신용품_쇼핑_검색.csv',
#  '2023_2030세대_호신용품_vs_가정용방범장치_쇼핑_검색.csv',
#  '2025_4050세대_호신용품_vs_가정용방범장치 _검색.xlsx',
#  '2025_2030세대_호신용품_vs_가정용방범장치 _검색.xlsx',
#  '2023_남자_호신용품_쇼핑_검색.csv',
#  '검색키워드',
#  '2024_여자_호신용품_쇼핑_검색.csv',
#  '2023_4050세대_호신용품_vs_가정용방범장치_쇼핑_검색.csv',
#  '2024_4050세대_호신용품_vs_가정용방범장치 _검색.xlsx',
#  '2024_남자_호신용품_쇼핑_검색.csv',
#  'project.ipynb',
#  '2024_2030세대_호신용품_vs_가정용방범장치 _검색.xlsx',
# ...

# %%
mans_2023 = pd.read_excel(io = '2023_남자_호신용관련_검색.xlsx',
                         skiprows = 6,
                         dtype = {'날짜' : 'datetime64[ns]', '호신용' : float})

girl_2023 = pd.read_excel(io = '2023_여자_호신용관련_검색.xlsx',
                         skiprows = 6,
                         dtype = {'날짜' : 'datetime64[ns]', '호신용' : float})

mans_2023['호신용'] = np.floor(mans_2023['호신용']+0.4).astype(int)
girl_2023['호신용'] = np.floor(girl_2023['호신용']+0.4).astype(int)

mans_2023['성별'] = '남'
girl_2023['성별'] = '여'

gdt_2023 = pd.concat([mans_2023 , girl_2023] , ignore_index = True)

sns.lineplot(data = gdt_2023 ,x= '날짜' , y = '호신용' , hue = '성별', estimator = 'mean')
plt.title(label = '2023년도 성별 호신용품 검색률 추이 그래프',fontweight = 'bold')
plt.ylim(0,110)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (0.0, 110.0)

# %%
mans_2024 = pd.read_excel(io = '2024_남자_호신용관련_검색.xlsx',
                         skiprows = 6,
                         dtype = {'날짜' : 'datetime64[ns]', '호신용' : float})

girl_2024 = pd.read_excel(io = '2024_여자_호신용관련_검색.xlsx',
                         skiprows = 6,
                         dtype = {'날짜' : 'datetime64[ns]', '호신용' : float})

mans_2024['호신용'] = np.floor(mans_2024['호신용']+0.4).astype(int)
girl_2024['호신용'] = np.floor(girl_2024['호신용']+0.4).astype(int)

mans_2024['성별'] = '남'
girl_2024['성별'] = '여'

gdt_2024 = pd.concat([mans_2024 , girl_2024] , ignore_index = True)

sns.lineplot(data = gdt_2024 ,x= '날짜' , y = '호신용' , hue = '성별', estimator = 'mean')
plt.title(label = '2024년도 성별 호신용품 검색률 추이 그래프',fontweight = 'bold')
plt.ylim(0,110)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (0.0, 110.0)

# %%
mans_2025 = pd.read_excel(io = '2025_남자_호신용관련_검색.xlsx',
                         skiprows = 6,
                         dtype = {'날짜' : 'datetime64[ns]', '호신용' : float})

girl_2025 = pd.read_excel(io = '2025_여자_호신용관련_검색.xlsx',
                         skiprows = 6,
                         dtype = {'날짜' : 'datetime64[ns]', '호신용' : float})

mans_2025['호신용'] = np.floor(mans_2025['호신용']+0.4).astype(int)
girl_2025['호신용'] = np.floor(girl_2025['호신용']+0.4).astype(int)

mans_2025['성별'] = '남'
girl_2025['성별'] = '여'

gdt_2025 = pd.concat([mans_2025 , girl_2025] , ignore_index = True)

sns.lineplot(data = gdt_2025 ,x= '날짜' , y = '호신용' , hue = '성별', estimator = 'mean')
plt.title(label = '2025년도 성별 호신용품 검색률 추이 그래프',fontweight = 'bold')
plt.ylim(0,110);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
gdt_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      712 non-null    datetime64[ns]
#  1   호신용     712 non-null    int64
#  2   성별      712 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 16.8+ KB

# %%
gdt_2023['월'] = gdt_2023['날짜'].dt.month
gdt_2024['월'] = gdt_2024['날짜'].dt.month
gdt_2025['월'] = gdt_2025['날짜'].dt.month

# %%
month_avg_2023 = gdt_2023.groupby('월')['호신용'].mean()
month_avg_2024 = gdt_2024.groupby('월')['호신용'].mean()
month_avg_2025 = gdt_2025.groupby('월')['호신용'].mean()

# %%
monthly_pct_change_2023 = month_avg_2023.pct_change() * 100
monthly_pct_change_2024 = month_avg_2024.pct_change() * 100
monthly_pct_change_2025 = month_avg_2025.pct_change() * 100

# %%
monthly_pct_change_2023 = monthly_pct_change_2023.apply(lambda x : 100 if np.isinf(x) else x).fillna(0)
monthly_pct_change_2024 = monthly_pct_change_2024.apply(lambda x : 100 if np.isinf(x) else x).fillna(0)
monthly_pct_change_2025 = monthly_pct_change_2025.apply(lambda x : 100 if np.isinf(x) else x).fillna(0)

# %%
monthly_pct_change_2023
# Out:
# 월
# 1        0.000000
# 2       10.714286
# 3       12.903226
# 4     -100.000000
# 5        0.000000
# 6      100.000000
# 7     1041.935484
# 8      190.254237
# 9      -94.720195
# 10    -100.000000
# 11       0.000000
# 12       0.000000
# Name: 호신용, dtype: float64

# %%
monthly_pct_change_2024
# Out:
# 월
# 1      0.000000
# 2     -3.876327
# 3     -6.676597
# 4     -3.791385
# 5      6.296253
# 6     -8.992614
# 7      7.135456
# 8     22.630561
# 9      0.929285
# 10   -10.922422
# 11   -21.548246
# 12    -6.692011
# Name: 호신용, dtype: float64

# %%
monthly_pct_change_2025
# Out:
# 월
# 1       0.000000
# 2      23.489011
# 3      -0.556174
# 4       3.333333
# 5     -25.092011
# 6      -5.327553
# 7      -0.172993
# 8      13.455657
# 9     245.372866
# 10    -16.805411
# 11    -61.225766
# 12    -10.000000
# Name: 호신용, dtype: float64

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_pct_change_2023]
monthly_pct_change_2023.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2023년 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_pct_change_2023):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_pct_change_2024]
#plt.figure(figsize = (12,6))
monthly_pct_change_2024.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2024년 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_pct_change_2024):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_pct_change_2025]
#plt.figure(figsize = (12,6))
monthly_pct_change_2025.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2025년 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_pct_change_2025):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
os.listdir()
# Out:
# ['2025_남자_호신용품_쇼핑_검색.csv',
#  '2023_2030세대_호신용품_쇼핑_검색.csv',
#  '2025_여자_호신용품_쇼핑_검색.csv',
#  '2025_2030세대_호신용관련_검색.xlsx',
#  '2024_4050세대_호신용품_vs_가정용방범장치_쇼핑_검색.csv',
#  '2024_2030세대_호신용품_쇼핑_검색.csv',
#  '2024_4050세대_호신용관련_검색.xlsx',
#  '2025_2030세대_호신용품_쇼핑_검색.csv',
#  '2023_2030세대_호신용품_vs_가정용방범장치_쇼핑_검색.csv',
#  '2025_4050세대_호신용품_vs_가정용방범장치 _검색.xlsx',
#  '2025_2030세대_호신용품_vs_가정용방범장치 _검색.xlsx',
#  '2023_남자_호신용품_쇼핑_검색.csv',
#  '검색키워드',
#  '2024_여자_호신용품_쇼핑_검색.csv',
#  '2023_4050세대_호신용품_vs_가정용방범장치_쇼핑_검색.csv',
#  '2024_4050세대_호신용품_vs_가정용방범장치 _검색.xlsx',
#  '2024_남자_호신용품_쇼핑_검색.csv',
#  'project.ipynb',
#  '2024_2030세대_호신용품_vs_가정용방범장치 _검색.xlsx',
# ...

# %%
total_2023 = pd.read_excel(io = '키워드사운드_호신용품_검색량_2023.xlsx',
                         dtype = {'날짜' : 'datetime64[ns]', '검색량' : int})
total_2024 = pd.read_excel(io = '키워드사운드_호신용품_검색량_2024.xlsx',
                         dtype = {'날짜' : 'datetime64[ns]', '검색량' : int})
total_2025 = pd.read_excel(io = '키워드사운드_호신용품_검색량_2025.xlsx',
                         dtype = {'날짜' : 'datetime64[ns]', '검색량' : int})

# %%
sns.lineplot(data = total_2023 ,x= '날짜' , y = '검색량')
plt.title(label = '2023년도 호신용품 검색률 추이 그래프',fontweight = 'bold')
# Out:
# Text(0.5, 1.0, '2023년도 호신용품 검색률 추이 그래프')

# %%
sns.lineplot(data = total_2024 ,x= '날짜' , y = '검색량')
plt.title(label = '2024년도 호신용품 검색률 추이 그래프',fontweight = 'bold')
# Out:
# Text(0.5, 1.0, '2024년도 호신용품 검색률 추이 그래프')

# %%
sns.lineplot(data = total_2025 ,x= '날짜' , y = '검색량')
plt.title(label = '2025년도 호신용품 검색률 추이 그래프',fontweight = 'bold')
# Out:
# Text(0.5, 1.0, '2025년도 호신용품 검색률 추이 그래프')

# %%
gen_2023 = gdt_2023.groupby([gdt_2023['날짜'].dt.month , '성별'])['호신용'].mean()

# %%
total_2023['월'] = total_2023['날짜'].dt.month
total_2024['월'] = total_2024['날짜'].dt.month
total_2025['월'] = total_2025['날짜'].dt.month

total_2023
# Out:
#             날짜  검색량   월
# 0   2023-01-01  460   1
# 1   2023-01-02  550   1
# 2   2023-01-03  550   1
# 3   2023-01-04  670   1
# 4   2023-01-05  530   1
# ..         ...  ...  ..
# 360 2023-12-27  420  12
# 361 2023-12-28  400  12
# 362 2023-12-29  330  12
# 363 2023-12-30  350  12
# 364 2023-12-31  390  12
#
# [365 rows x 3 columns]

# %%
total_2023.groupby('월')['검색량'].mean()
# Out:
# 월
# 1       527.741935
# 2       580.714286
# 3       504.193548
# 4       533.000000
# 5       440.322581
# 6       698.666667
# 7      6401.612903
# 8     17516.129032
# 9       910.666667
# 10      528.709677
# 11      435.000000
# 12      408.709677
# Name: 검색량, dtype: float64

# %%
total_2023.groupby('월')['검색량'].sum()
# Out:
# 월
# 1      16360
# 2      16260
# 3      15630
# 4      15990
# 5      13650
# 6      20960
# 7     198450
# 8     543000
# 9      27320
# 10     16390
# 11     13050
# 12     12670
# Name: 검색량, dtype: int64

# %%
total_2023['남자검색량'] = (total_2023['검색량'] * 0.48).round().astype(int)
total_2023['여자검색량'] = (total_2023['검색량'] * 0.52).round().astype(int)

total_2024['남자검색량'] = (total_2024['검색량'] * 0.53).round().astype(int)
total_2024['여자검색량'] = (total_2024['검색량'] * 0.47).round().astype(int)

total_2025['남자검색량'] = (total_2025['검색량'] * 0.48).round().astype(int)
total_2025['여자검색량'] = (total_2025['검색량'] * 0.52).round().astype(int)

total_2023
# Out:
#             날짜  검색량   월  남자검색량  여자검색량
# 0   2023-01-01  460   1    221    239
# 1   2023-01-02  550   1    264    286
# 2   2023-01-03  550   1    264    286
# 3   2023-01-04  670   1    322    348
# 4   2023-01-05  530   1    254    276
# ..         ...  ...  ..    ...    ...
# 360 2023-12-27  420  12    202    218
# 361 2023-12-28  400  12    192    208
# 362 2023-12-29  330  12    158    172
# 363 2023-12-30  350  12    168    182
# 364 2023-12-31  390  12    187    203
#
# [365 rows x 5 columns]

# %%
month_avg_2023 = total_2023.groupby('월')['검색량'].mean()
month_avg_2024 = total_2024.groupby('월')['검색량'].mean()
month_avg_2025 = total_2025.groupby('월')['검색량'].mean()

month_avg_man_2023 = total_2023.groupby('월')['남자검색량'].mean()
month_avg_girl_2023 = total_2023.groupby('월')['여자검색량'].mean()

month_avg_man_2024 = total_2024.groupby('월')['남자검색량'].mean()
month_avg_girl_2024 = total_2024.groupby('월')['여자검색량'].mean()

month_avg_man_2025 = total_2025.groupby('월')['남자검색량'].mean()
month_avg_girl_2025 = total_2025.groupby('월')['여자검색량'].mean()

# %%
monthly_pct_change_2023 = month_avg_2023.pct_change() * 100
monthly_pct_change_2024 = month_avg_2024.pct_change() * 100
monthly_pct_change_2025 = month_avg_2025.pct_change() * 100

monthly_man_pct_change_2023 = month_avg_man_2023.pct_change() * 100
monthly_girl_pct_change_2023 = month_avg_girl_2023.pct_change() * 100

monthly_man_pct_change_2024 = month_avg_man_2024.pct_change() * 100
monthly_girl_pct_change_2024 = month_avg_girl_2024.pct_change() * 100

monthly_man_pct_change_2025 = month_avg_man_2025.pct_change() * 100
monthly_girl_pct_change_2025 = month_avg_girl_2025.pct_change() * 100

# %%
monthly_pct_change_2023
# Out:
# 월
# 1            NaN
# 2      10.037548
# 3     -13.177003
# 4       5.713372
# 5     -17.387884
# 6      58.671551
# 7     816.261389
# 8     173.620559
# 9     -94.800982
# 10    -41.942568
# 11    -17.724222
# 12     -6.043752
# Name: 검색량, dtype: float64

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_man_pct_change_2023]
monthly_man_pct_change_2023.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2023년 남자 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_man_pct_change_2023):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_girl_pct_change_2023]
monthly_girl_pct_change_2023.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2023년 여자 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_girl_pct_change_2023):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_man_pct_change_2024]
monthly_man_pct_change_2024.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2024년 남자 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_man_pct_change_2024):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_girl_pct_change_2024]
monthly_girl_pct_change_2024.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2024년 여자 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_girl_pct_change_2024):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_man_pct_change_2025]
monthly_man_pct_change_2025.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2025년 남자 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_man_pct_change_2025):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_girl_pct_change_2025]
monthly_girl_pct_change_2025.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2025년 여자 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_girl_pct_change_2025):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_pct_change_2023]
monthly_pct_change_2023.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2023년 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_pct_change_2023):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_pct_change_2024]
monthly_pct_change_2024.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2024년 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_pct_change_2024):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')

# %%
monthly_pct_change_2025
# Out:
# 월
# 1            NaN
# 2      24.996193
# 3      -4.815864
# 4      -1.388889
# 5     -14.039073
# 6      -6.825229
# 7       6.531029
# 8      14.376997
# 9     303.519553
# 10    -25.331118
# 11    -64.331479
# 12    -16.863352
# Name: 검색량, dtype: float64

# %%
colors = ['red' if x >= 0 else 'blue' for x in monthly_pct_change_2025]
monthly_pct_change_2025.plot(kind = 'bar' , color = colors)
plt.axhline(0 , color = 'black' , linewidth = 1)
plt.title('2025년 호신용품 검색 증감률 (%)' , fontsize = 15)
plt.xticks(rotation = 360)
plt.xlabel('월')
plt.ylabel('전월 대비 증감률(%)');

for i , v in enumerate(monthly_pct_change_2025):
    plt.text(i,v, f'{v:.1f}%' , ha = 'center' , va = 'bottom' if v > 0 else 'top')
