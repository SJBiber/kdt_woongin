# %% [markdown]
# # Seoul Subway Data Analysis
#
# ## Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
from supabase import create_client
from dotenv import load_dotenv
import os

load_dotenv()

# Connect to DB
SUPABASE_URL = os.getenv("SUPABASE_URL")
SUPABASE_KEY = os.getenv("SUPABASE_KEY")
supabase = create_client(SUPABASE_URL, SUPABASE_KEY)

# %% [markdown]
# ## 1. Load Data
# Fetch data from 'realtime_subway_positions' table.

# %%
# Example Query
# response = supabase.table("realtime_subway_positions").select("*").execute()
# df = pd.DataFrame(response.data)
# df['reception_time'] = pd.to_datetime(df['reception_time'])
# df.head()

# %% [markdown]
# ## 2. Analysis Projects
#
# ### A. Real-time Operation Status
# Visualize train locations.

# %%
# Code for Project A
